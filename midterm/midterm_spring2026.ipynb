# %% [markdown]
# # Midterm Spring 2026
#
# ## Project Overview
#
# You have been hired by a data science company to complete a specific analytical task. Your responsibility is to complete the task and present your results in a notebook.
#
# **Important:** Your audience (stakeholders, managers, and decision-makers) is not interested in code implementation details or technical minutiae. They want to understand:
#
# - **Your findings** - What insights did you discover?
# - **Your solution** - What approach did you take and why?
# - **The results** - What are the outcomes and recommendations?
#
# Focus on clear, concise explanations of your analysis, methodology, and conclusions. Use visualizations and summaries to communicate effectively. The code should support your narrative, not dominate it.
#
# **Rubric** https://docs.google.com/spreadsheets/d/1NUxHvnWQDmvURRL1pUzob9vZdd2vPd_j/edit?gid=1231348425#gid=1231348425

# %% [markdown]
# # Option1

# %%
from IPython.display import Markdown, display
display(Markdown("churn_dataset_documentation.md"))
# Out:
# # Streaming Service Customer Churn Prediction
#
# ## Business Context
#
# **StreamFlix** is a popular streaming service that wants to identify customers who are likely to cancel their subscription within the next 30 days. Early identification allows the company to implement targeted retention strategies (personalized recommendations, offers, support outreach) to reduce churn and maintain revenue.
#
# This is a **binary classification** task: you have labeled data and must build a model to predict `will_churn` (0 = will not churn, 1 = will churn).
#
# ## Dataset Overview
#
# - **Total Records**: 10,000
# - **Features**: 37
# - **Target Variable**: `will_churn` (0 or 1)
# - **Missing Values**: 2,500
# - **Churn Rate**: 18.89%
# - **Class Distribution**: {0: 8111, 1: 1889}
#
# ## Feature Categories
#
# ### 1. Subscription Features
# - `subscription_start_date`: Date when customer first subscribed
# - `subscription_length_days`, `subscription_length_months`: Tenure
# - `subscription_plan`: basic, standard, premium, family, student
# - `monthly_price`: Monthly subscription price ($)
# - `billing_cycle`: monthly, annual
# - `payment_method`: credit_card, debit_card, paypal, apple_pay, google_pay, bank_transfer
#
# ### 2. Usage Behavioral Features (Last 30 Days)
# - `total_watch_time_hours`, `sessions_count`, `avg_session_duration_minutes`
# - `days_since_last_watch`, `unique_titles_watched`, `content_completion_rate`
# - `abandoned_series_count`, `binge_sessions_count`
#
# ### 3. Content Preference Features
# - `primary_genre`, `genres_watched_count`, `genres_watched` (text)
# - `content_type_preference`: movies, tv_shows, both
# - `new_content_ratio`
#
# ### 4. Device and Platform Features
# - `primary_device`, `devices_used_count`, `devices_used` (text), `primary_os`
#
# ### 5. Engagement and Interaction Features
# - `has_profile`, `number_of_profiles`, `watchlist_size`
# - `ratings_given_count`, `reviews_written_count`, `downloads_count`
#
# ### 6. Support and Service Features
# - `support_tickets_count`, `support_ticket_reasons` (text)
# - `payment_failures_count`, `account_on_hold`, `used_free_trial`
#
# ### 7. Temporal Features
# - `current_month`, `days_until_next_billing`
#
# ### 8. Target
# - `will_churn`: 1 if customer will churn in the next 30 days, 0 otherwise

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS_data/master/ds602/2026/streaming_churn.csv')
df.shape
# Out:
# (10000, 38)

# %%
df.head().T
# Out:
#                                                                    0  \
# subscription_start_date                                   2023-03-13
# subscription_length_days                                         659
# subscription_plan                                           standard
# monthly_price                                                  15.99
# billing_cycle                                                monthly
# payment_method                                                paypal
# total_watch_time_hours                                       5.17082
# sessions_count                                              3.015887
# avg_session_duration_minutes                                103.9745
# days_since_last_watch                                       4.971187
# unique_titles_watched                                       4.711314
# content_completion_rate                                     0.115845
# abandoned_series_count                                             2
# binge_sessions_count                                               0
# primary_genre                                            Documentary
# genres_watched_count                                               5
# content_type_preference                                       movies
# new_content_ratio                                           0.091304
# primary_device                                                mobile
# devices_used_count                                                 2
# primary_os                                                       iOS
# has_profile                                                        0
# number_of_profiles                                                 1
# watchlist_size                                             19.171024
# ratings_given_count                                              4.0
# reviews_written_count                                            2.0
# downloads_count                                                    1
# support_tickets_count                                              0
# payment_failures_count                                             0
# account_on_hold                                                    0
# used_free_trial                                                    0
# subscription_length_months                                        21
# current_month                                                     12
# days_until_next_billing                                           15
# genres_watched                Thriller, Anime, Drama, Sports, Horror
# devices_used                                        smart_tv, mobile
# support_ticket_reasons                                           NaN
# will_churn                                                         0
#
#                                                                   1  \
# subscription_start_date                                  2020-02-15
# subscription_length_days                                       1781
# subscription_plan                                           student
# monthly_price                                                  7.99
# billing_cycle                                               monthly
# payment_method                                          credit_card
# total_watch_time_hours                                   173.005893
# sessions_count                                            87.408494
# avg_session_duration_minutes                             116.887515
# days_since_last_watch                                       2.61486
# unique_titles_watched                                     47.003151
# content_completion_rate                                    0.789242
# abandoned_series_count                                            2
# binge_sessions_count                                              7
# primary_genre                                                 Drama
# genres_watched_count                                              2
# content_type_preference                                      movies
# new_content_ratio                                          0.113532
# primary_device                                         game_console
# devices_used_count                                                4
# primary_os                                                  Android
# has_profile                                                       0
# number_of_profiles                                                1
# watchlist_size                                            13.376992
# ratings_given_count                                             1.0
# reviews_written_count                                           1.0
# downloads_count                                                   3
# support_tickets_count                                             1
# payment_failures_count                                            1
# account_on_hold                                                   0
# used_free_trial                                                   1
# subscription_length_months                                       59
# current_month                                                    12
# days_until_next_billing                                           9
# genres_watched                                        Drama, Sci-Fi
# devices_used                  mobile, desktop, tablet, game_console
# support_ticket_reasons                              content_request
# will_churn                                                        0
#
#                                                                         2  \
# subscription_start_date                                        2021-05-17
# subscription_length_days                                             1324
# subscription_plan                                                 premium
# monthly_price                                                       19.99
# billing_cycle                                                     monthly
# payment_method                                                credit_card
# total_watch_time_hours                                         177.950326
# sessions_count                                                      109.0
# avg_session_duration_minutes                                    93.389997
# days_since_last_watch                                            1.919463
# unique_titles_watched                                            17.30011
# content_completion_rate                                          0.491299
# abandoned_series_count                                                  3
# binge_sessions_count                                                    4
# primary_genre                                                      Comedy
# genres_watched_count                                                    2
# content_type_preference                                            movies
# new_content_ratio                                                0.358115
# primary_device                                                     tablet
# devices_used_count                                                      4
# primary_os                                                           tvOS
# has_profile                                                             1
# number_of_profiles                                                      2
# watchlist_size                                                  17.194595
# ratings_given_count                                                  12.0
# reviews_written_count                                                 1.0
# downloads_count                                                         7
# support_tickets_count                                                   0
# payment_failures_count                                                  0
# account_on_hold                                                         0
# used_free_trial                                                         1
# subscription_length_months                                             44
# current_month                                                          12
# days_until_next_billing                                                17
# genres_watched                                             Comedy, Horror
# devices_used                  desktop, smart_tv, streaming_device, mobile
# support_ticket_reasons                                                NaN
# will_churn                                                              0
#
#                                                          3  \
# subscription_start_date                         2021-02-11
# subscription_length_days                              1419
# subscription_plan                                  premium
# monthly_price                                        19.99
# billing_cycle                                      monthly
# payment_method                                      paypal
# total_watch_time_hours                           29.313555
# sessions_count                                    6.723148
# avg_session_duration_minutes                    187.994139
# days_since_last_watch                             3.537331
# unique_titles_watched                            11.016892
# content_completion_rate                           0.162234
# abandoned_series_count                                   1
# binge_sessions_count                                     0
# primary_genre                                       Comedy
# genres_watched_count                                     2
# content_type_preference                             movies
# new_content_ratio                                 0.182729
# primary_device                                game_console
# devices_used_count                                       3
# primary_os                                            tvOS
# has_profile                                              1
# number_of_profiles                                       1
# watchlist_size                                    6.217699
# ratings_given_count                                    3.0
# reviews_written_count                                  1.0
# downloads_count                                          3
# support_tickets_count                                    0
# payment_failures_count                                   0
# account_on_hold                                          0
# used_free_trial                                          0
# subscription_length_months                              47
# current_month                                           12
# days_until_next_billing                                 20
# genres_watched                               Horror, Drama
# devices_used                  tablet, game_console, mobile
# support_ticket_reasons                                 NaN
# will_churn                                               0
#
#                                                      4
# subscription_start_date                     2023-09-06
# subscription_length_days                           482
# subscription_plan                                basic
# monthly_price                                     9.99
# billing_cycle                                  monthly
# payment_method                              debit_card
# total_watch_time_hours                        8.381127
# sessions_count                                4.719065
# avg_session_duration_minutes                100.288519
# days_since_last_watch                         8.166934
# unique_titles_watched                         3.883085
# content_completion_rate                       0.219525
# abandoned_series_count                               2
# binge_sessions_count                                 0
# primary_genre                                   Action
# genres_watched_count                                 2
# content_type_preference                           both
# new_content_ratio                             0.205435
# primary_device                                  tablet
# devices_used_count                                   3
# primary_os                                         iOS
# has_profile                                          0
# number_of_profiles                                   1
# watchlist_size                               16.833278
# ratings_given_count                                4.0
# reviews_written_count                              0.0
# downloads_count                                      1
# support_tickets_count                                1
# payment_failures_count                               0
# account_on_hold                                      0
# used_free_trial                                      1
# subscription_length_months                          16
# current_month                                       12
# days_until_next_billing                             18
# genres_watched                   Thriller, Documentary
# devices_used                  mobile, smart_tv, tablet
# support_ticket_reasons                             NaN
# will_churn                                           1

# %%
df.will_churn.hist()
# Out:
# <Axes: >

# %% [markdown]
# # Option2

# %%
display(Markdown("ecommerce_dataset_documentation.md"))
# Out:
# # E-commerce Customer Purchase Prediction
#
# ## Business Context
#
# **Company A Solutions** is an e-commerce analytics company hired by online retailers to predict which customers are likely to make a purchase during their browsing session. This helps optimize marketing spend, personalize user experience in real-time, and improve conversion rates.
#
# This is a **binary classification** task: you have labeled data and must build a model to predict `will_purchase` (0 = will not purchase, 1 = will purchase).
#
# ## Dataset Overview
#
# - **Total Records**: 10,000
# - **Features**: 26
# - **Target Variable**: `will_purchase` (0 or 1)
# - **Missing Values**: 2,000
# - **Purchase Rate**: 51.41%
# - **Class Distribution**: {1: 5141, 0: 4859}
#
# ## Feature Categories
#
# ### 1. Temporal Features
# - `session_start_time`: Timestamp when session began
# - `hour`: Hour of day (0-23)
# - `day_of_week`: Day of week (0=Monday, 6=Sunday)
# - `month`: Month (1-12)
# - `is_weekend`: Binary flag for weekend (1) vs weekday (0)
# - `session_duration_minutes`: Length of session in minutes
# - `days_since_last_visit`: Days since customer's last visit
#
# ### 2. Behavioral Numerical Features
# - `page_views`: Number of pages viewed during session
# - `clicks`: Number of clicks made during session
# - `avg_scroll_depth`: Average scroll depth (0-1)
# - `items_added_to_cart`: Number of items added to cart
# - `items_removed_from_cart`: Number of items removed from cart
# - `search_queries_count`: Number of search queries made
# - `product_page_time_minutes`: Time spent on product pages
# - `categories_viewed_count`: Number of different categories viewed
# - `avg_price_viewed`: Average price of products viewed ($)
#
# ### 3. Categorical Features
# - `device_type`: mobile, desktop, tablet
# - `traffic_source`: organic_search, paid_search, social_media, email, direct, referral
# - `customer_segment`: new_customer, returning_customer, vip_customer, at_risk_customer
# - `region`: North_America, Europe, Asia_Pacific, Latin_America, Middle_East_Africa
# - `browser`: Chrome, Safari, Firefox, Edge, Other
# - `operating_system`: Windows, macOS, iOS, Android, Linux
# - `user_type`: new_user, returning_user
#
# ### 4. Text Features
# - `search_queries`: Comma-separated search terms used
# - `categories_viewed`: Comma-separated product categories viewed
# - `user_agent`: Browser user agent string
#
# ### 5. Target
# - `will_purchase`: 1 if customer made (or will make) a purchase in the session, 0 otherwise

# %%
df = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS_data/master/ds602/2026/ecommerce_purchase.csv')
df.shape
# Out:
# (10000, 27)

# %%
df.head().T
# Out:
#                                                                            0  \
# session_start_time                                       2024-02-02 07:39:08
# hour                                                                       7
# day_of_week                                                                4
# month                                                                      2
# is_weekend                                                                 0
# session_duration_minutes                                            4.241725
# days_since_last_visit                                               3.033577
# page_views                                                          0.962865
# clicks                                                                   0.0
# avg_scroll_depth                                                     0.18276
# items_added_to_cart                                                        4
# items_removed_from_cart                                                    3
# search_queries_count                                                       1
# product_page_time_minutes                                           0.931498
# categories_viewed_count                                                    2
# avg_price_viewed                                                    4.716522
# device_type                                                           mobile
# traffic_source                                                organic_search
# customer_segment                                          returning_customer
# region                                                    Middle_East_Africa
# browser                                                               Chrome
# operating_system                                                         iOS
# user_type                                                     returning_user
# search_queries                                                  summer dress
# categories_viewed                                 Home & Garden, Baby & Kids
# user_agent                 Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like M...
# will_purchase                                                              0
#
#                                                                            1  \
# session_start_time                                       2024-12-12 15:37:55
# hour                                                                      15
# day_of_week                                                                3
# month                                                                     12
# is_weekend                                                                 0
# session_duration_minutes                                            5.000125
# days_since_last_visit                                               7.316292
# page_views                                                          0.996749
# clicks                                                                   0.0
# avg_scroll_depth                                                    0.761853
# items_added_to_cart                                                        2
# items_removed_from_cart                                                    0
# search_queries_count                                                       1
# product_page_time_minutes                                           0.851462
# categories_viewed_count                                                    4
# avg_price_viewed                                                   26.920076
# device_type                                                           mobile
# traffic_source                                                  social_media
# customer_segment                                          returning_customer
# region                                                          Asia_Pacific
# browser                                                               Chrome
# operating_system                                                     Windows
# user_type                                                     returning_user
# search_queries                                                       perfume
# categories_viewed          Tools & Hardware, Clothing, Electronics, Baby ...
# user_agent                 Mozilla/5.0 (Linux; Android 11; SM-G991B) Appl...
# will_purchase                                                              1
#
#                                                                            2  \
# session_start_time                                       2024-02-24 19:33:54
# hour                                                                      19
# day_of_week                                                                5
# month                                                                      2
# is_weekend                                                                 1
# session_duration_minutes                                           10.552687
# days_since_last_visit                                               0.432975
# page_views                                                          1.984853
# clicks                                                              1.012054
# avg_scroll_depth                                                    0.533179
# items_added_to_cart                                                        1
# items_removed_from_cart                                                    0
# search_queries_count                                                       2
# product_page_time_minutes                                           0.946506
# categories_viewed_count                                                    2
# avg_price_viewed                                                   15.779476
# device_type                                                          desktop
# traffic_source                                                  social_media
# customer_segment                                          returning_customer
# region                                                                Europe
# browser                                                              Firefox
# operating_system                                                     Windows
# user_type                                                     returning_user
# search_queries                                            perfume, new dress
# categories_viewed                                        Shoes, Pet Supplies
# user_agent                 Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# will_purchase                                                              0
#
#                                                                            3  \
# session_start_time                                       2024-09-26 12:46:30
# hour                                                                      12
# day_of_week                                                                3
# month                                                                      9
# is_weekend                                                                 0
# session_duration_minutes                                           18.705162
# days_since_last_visit                                               3.612518
# page_views                                                          2.980036
# clicks                                                              1.027641
# avg_scroll_depth                                                    0.538472
# items_added_to_cart                                                        5
# items_removed_from_cart                                                    2
# search_queries_count                                                       1
# product_page_time_minutes                                           0.537198
# categories_viewed_count                                                    1
# avg_price_viewed                                                   11.990575
# device_type                                                          desktop
# traffic_source                                                organic_search
# customer_segment                                                new_customer
# region                                                         North_America
# browser                                                               Chrome
# operating_system                                                     Windows
# user_type                                                           new_user
# search_queries                                                   dress shoes
# categories_viewed                                                        NaN
# user_agent                 Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# will_purchase                                                              0
#
#                                                                            4
# session_start_time                                       2024-11-03 18:30:12
# hour                                                                      18
# day_of_week                                                                6
# month                                                                     11
# is_weekend                                                                 1
# session_duration_minutes                                             6.36049
# days_since_last_visit                                                9.74639
# page_views                                                          1.077701
# clicks                                                                   0.0
# avg_scroll_depth                                                    0.590819
# items_added_to_cart                                                        5
# items_removed_from_cart                                                    2
# search_queries_count                                                       1
# product_page_time_minutes                                           2.348161
# categories_viewed_count                                                    1
# avg_price_viewed                                                    9.083236
# device_type                                                          desktop
# traffic_source                                                organic_search
# customer_segment                                                new_customer
# region                                                         Latin_America
# browser                                                               Chrome
# operating_system                                                         iOS
# user_type                                                     returning_user
# search_queries                                                 gaming laptop
# categories_viewed                                                Electronics
# user_agent                 Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# will_purchase                                                              1

# %%
df.will_purchase.hist()
# Out:
# <Axes: >
