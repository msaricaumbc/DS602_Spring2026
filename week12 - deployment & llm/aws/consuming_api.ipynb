# %%
import requests
import json
import urllib

# %%
sentence = "awesome movie but fell asleep"

# %%
ip = '54.89.233.250/'
sentence_encoded = urllib.parse.quote(sentence)
url = f'http://{ip}/?sentence={sentence_encoded}'
print(url)
# Out:
# http://54.89.233.250//?sentence=awesome%20movie%20but%20fell%20asleep

# %%
json.loads(requests.get(url ).text)
# Out:
# {'sentence': 'awesome movie but fell asleep', 'sentiment': 'positive'}

# %%
def predict_sentiment(sentence):
    sentence_encoded = urllib.parse.quote(sentence)
    url = f'http://{ip}/?sentence={sentence_encoded}'
    response = json.loads(requests.get(url ).text)
    prediction = response['sentiment']
    print(prediction)
    return prediction

# %%
while True:
    sentence = input('>>')
    if not sentence or sentence.strip() == '':
        break

    predict_sentiment(sentence)
# Out:
# >> it was an ok movie
# negative
# >> it was very boooooring
# positive
# >> very boring
# negative
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 while True:
# ----> 2     sentence = input('>>')
#       3     if not sentence or sentence.strip() == '':
#       4         break
#
# File /opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# ...
